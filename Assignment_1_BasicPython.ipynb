# %% [markdown]
# <a href="https://colab.research.google.com/github/NairMpc/DataScience/blob/main/Assignment_1_BasicPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BASIC PYTHON.

# %% [markdown]
# # Exercise-1. Prime number

# %% [markdown]
# ##### write a program that checks whether a given number is prime.
# A number is prime if it has no factors other than it and 1.
# To find whether a number N is prime , we check divisibility starting from 2 and consecutively till square root of N. if N is divisible by any number break there and say is_prime = False. Else continue the loop and is_prime = True.
#
# (if N=a*b, then one of the factor must be <= √N. That is why we are checking divisibility til √N.)

# %%
num = int(input("Enter a number: "))
if num <= 1:
  print(num, "is neither prime nor composite")
else:
  is_prime = True
  for i in range(2, int(num**0.5) + 1):
    if num % i == 0:
      is_prime = False
      break
  if is_prime:
    print(num, "is a prime number")
  else:
    print(num, "is not a prime number")
# Out:
# Enter a number: 19
# 19 is a prime number

# %% [markdown]
# # Exercise 2: Product of Random Numbers
#
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import numpy as np
num1, num2 = np.random.randint(1,100,2)
print(f"Random Numberr-1: {num1}")
print(f"Random Numberr-2: {num2}")

prod = int(input("Enter the product of the two random numbers: "))
if prod == num1 * num2:
  print("Correct Answer")
else:
  print(f"Incorrect Answer: Crrect Product is:{num1*num2}")
# Out:
# Random Numberr-1: 75
# Random Numberr-2: 48
# Enter the product of the two random numbers: 3500
# Incorrect Answer: Crrect Product is:3600

# %% [markdown]
# # Exercise 3: Squares of Even/Odd Numbers
#
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
print("Even numbers in the range (100,200):")
for itr in range(100,200,2):
  print(itr, end=' ')
# Out:
# Even numbers in the range (100,200):
# 100 102 104 106 108 110 112 114 116 118 120 122 124 126 128 130 132 134 136 138 140 142 144 146 148 150 152 154 156 158 160 162 164 166 168 170 172 174 176 178 180 182 184 186 188 190 192 194 196 198

# %%
print("Odd numbers in the range (100,200):")

for itr in range(101,200,2):
  print(itr,end=' ')
# Out:
# Odd numbers in the range (100,200):
# 101 103 105 107 109 111 113 115 117 119 121 123 125 127 129 131 133 135 137 139 141 143 145 147 149 151 153 155 157 159 161 163 165 167 169 171 173 175 177 179 181 183 185 187 189 191 193 195 197 199

# %%
print("Seperate lists of even and odd numbers within the range (100,200)")
even_nums = []
odd_nums = []
for num in range(100,200):
  if num % 2 == 0:
    even_nums.append(num)
  else:
    odd_nums.append(num)
print(f"Even Numbers: {even_nums}")
print(f"Odd Numbers: {odd_nums}")
# Out:
# Seperate lists of even and odd numbers within the range (100,200
# Even Numbers: [100, 102, 104, 106, 108, 110, 112, 114, 116, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 140, 142, 144, 146, 148, 150, 152, 154, 156, 158, 160, 162, 164, 166, 168, 170, 172, 174, 176, 178, 180, 182, 184, 186, 188, 190, 192, 194, 196, 198]
# Odd Numbers: [101, 103, 105, 107, 109, 111, 113, 115, 117, 119, 121, 123, 125, 127, 129, 131, 133, 135, 137, 139, 141, 143, 145, 147, 149, 151, 153, 155, 157, 159, 161, 163, 165, 167, 169, 171, 173, 175, 177, 179, 181, 183, 185, 187, 189, 191, 193, 195, 197, 199]

# %% [markdown]
# # Exercise 4:
# ✅ Problem Statement (Question): Hospital Billing System.
#
# A hospital charges its patients based on the following:
#
# •	Room charges per day: ₹2,000
#
# •	Doctor consultation fee (flat): ₹1,500
#
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
#
# •	Medicine charges: Total cost of medicines provided
#
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
#
# Write a Python program to calculate the final bill for a patient who:
#
# •	Stayed for 4 days
#
# •	Had 3 lab tests
#
# •	Had medicine charges of ₹2,400

# %%
print("HOSPITAL BILLING SYSTEM")
room_charges = 2000
doctor_fee = 1500
lab_test_charges = 300
num_days = int(input("Enter the number of days:"))
lab_tests = int(input("Enter the number of lab tests:"))
med_charges = int(input("Enter the medicine charges:"))
total_bill = room_charges * num_days + doctor_fee + lab_test_charges * lab_tests + med_charges
if total_bill > 10000:
  pay_bill = total_bill * 0.9
else:
  pay_bill = total_bill
print(f"Total Bill: {total_bill}")
print(f"Bill Payable:{pay_bill}")
# Out:
# HOSPITAL BILLING SYSTEM
# Enter the number of days:2
# Enter the number of lab tests:1
# Enter the medicine charges:2400
# Total Bill: 8200
# Bill Payable:8200
